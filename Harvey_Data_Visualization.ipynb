# %%
import numpy as np
import pandas as pd

# %%
chunksize = 1000 
for chunk in pd.read_json("/corral-repl/utexas/Trump-Tweets/Harvey/unt_data/harvey_twitter_dataset/02_archive_only/HurricaneHarvey.json", chunksize=chunksize,lines=True):
    f=pd.DataFrame(chunk)
    print(f.head())
# Out:
#    contributors  coordinates          created_at  \
# 0           NaN          NaN 2017-08-27 11:54:25
# 1           NaN          NaN 2017-08-27 11:54:24
# 2           NaN          NaN 2017-08-27 11:54:23
# 3           NaN          NaN 2017-08-27 11:54:22
# 4           NaN          NaN 2017-08-27 11:54:22
#
#                                             entities extended_entities  \
# 0  {'symbols': [], 'user_mentions': [{'indices': ...               NaN
# 1  {'symbols': [], 'user_mentions': [{'indices': ...               NaN
# 2  {'symbols': [], 'user_mentions': [{'indices': ...               NaN
# 3  {'symbols': [], 'user_mentions': [{'indices': ...               NaN
# 4  {'symbols': [], 'user_mentions': [{'indices': ...               NaN
#
#    favorite_count  favorited  geo                  id              id_str  \
# 0               0      False  NaN  901774900481970176  901774900481970176
# 1               0      False  NaN  901774898623692800  901774898623692800
# ...

# %%
frame.head()
